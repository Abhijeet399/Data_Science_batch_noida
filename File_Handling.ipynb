# %%
file = open("/home/abhijeet/Desktop/Data_Science_batch_noida/hello.txt", 'r')

# %%
file.read(5)
# Out:
# 'hello'

# %%
file.read()
# Out:
# ' world\nhi\nmy name is abhijeet\n'

# %%
file.seek(0)
# Out:
# 0

# %%
file.read()
# Out:
# 'hello world\nhi\nmy name is abhijeet\n'

# %%
file.close()

# %%
with open("/home/abhijeet/Desktop/Data_Science_batch_noida/hello.txt", 'r') as file:
    print(file.read())
# Out:
# hello world
# hi
# my name is abhijeet

# %%
file.readlines()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 file.readlines()
#
# ValueError: I/O operation on closed file.

# %%
# file.close()

# %%
file.readline()
# Out:
# ''

# %%
file.readlines()[0]
# Out:
# 'hello world\n'

# %%
file.close()

# %%
file2 = open("temp.txt", 'w')

# %%
file2.write("Hello")
# Out:
# 5

# %%
file2.close()

# %% [markdown]
# # JSON

# %%
with open("/home/abhijeet/Desktop/Jupyter_Notebook/3D_reconstruction/Dataset_collection/Json_annotations/BTcode.json", 'r') as data:
    print(data.read())
    print(type(data.read()))
# Out:
# {
#     "0": {
#         "BTcode": "1111111",
#         "questions": [
#             "round-off onto the springboard?",
#             "turning entry after round-off (turning in first flight phase)?",
#             "Facing the coming direction when handstand on vault (half turn in first flight phase)?",
#             "Body keep stretched  during salto (stretched salto)?",
#             "Salto with turn?",
#             "Facing vault table after landing?",
#             "Salto with One point five turn?"
#         ],
#         "code": "6.00"
#     },
#     "1": {
#         "BTcode": "1111110",
#         "questions": [
#             "round-off onto the springboard?",
#             "turning entry after round-off (turning in first flight phase)?",
#             "Facing the coming direction when handstand on vault (half turn in first flight phase)?",
#             "Body keep stretched  during salto (stretched salto)?",
#             "Salto with turn?",
# ...

# %%
import json

# %%
with open("/home/abhijeet/Desktop/Jupyter_Notebook/3D_reconstruction/Dataset_collection/Json_annotations/BTcode.json", 'r') as data:
#     print(data.read())
#     print(type(data.read()))
    d = json.load(data)
    print(d["50"])
# Out:
# {'BTcode': '0001011011', 'questions': ['round-off onto the springboard?', 'Tsukahara (front handspring with half or quater turn in pre-flight) ?', 'Twisting body before touching the vault table?', 'Salto off?', 'body keep stretched  during salto (stretched salto)?', 'Pike salto (body bent forward at the waist with the legs kept stretched )?', 'Salto with turn?', 'half turn with body being stretched before salto?', 'Facing vault table after landing?', 'One point five turn?'], 'code': '5.40'}

# %%
d = {
    "name":"ABhijeet",
    "age": 22,
    "marks":30
}

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
with open("temp_json.json", 'w') as file:
#     str = json.dumps(d)
    print(str)
    json.dump(d, file)
# Out:
# {"name": "ABhijeet", "age": 22, "marks": 30}

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
def div(a, b):
    try:
        print(a/b)
#     except ValueError:
#         print("Value Error")
#     except ZeroDivisionError:
#         print("Zero Error")
#     except Exception as e:
#         print(str(e))
    except:
        raise Exception("My custom error")
    finally:
        print("Chalega hi chalega")

# %%
div(10, "hello")
# Out:
# Chalega hi chalega
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in div(a, b)
#       2     try:
# ----> 3         print(a/b)
#       4 #     except ValueError:
#       5 #         print("Value Error")
#       6 #     except ZeroDivisionError:
#       7 #         print("Zero Error")
#       8 #     except Exception as e:
#       9 #         print(str(e))
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 div(10, "hello")
#
# Input In [79], in div(a, b)
#       4 #     except ValueError:
#       5 #         print("Value Error")
#       6 #     except ZeroDivisionError:
#       7 #         print("Zero Error")
#       8 #     except Exception as e:
# ...
